# %% [markdown]
# #  <center>  Web-Scrapping des infos des freelancers avec agences  <center>
#
# Nous avons obtenue 1780 de idtentification mais nous avons réussi collecter 365 oberservations parmi eux.

# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import copy

# %% [markdown]
# COMMENCE A 11:32 FINIR A 12:18

# %% [markdown]
# ## Récupérer les identifications

# %%
headers = {
  'host': 'www.upwork.com',
  'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
  'accept':'accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
  'cookie': 'visitor_id=195.83.48.81.1637071873989010; lang=en; spt=5687a8e3-0b6f-458b-9ec7-5ea26a788067; _pxvid=0eabb6f8-46e7-11ec-9a3b-4e746f635050; _gcl_au=1.1.539077891.1637071917; cb_user_id=null; cb_group_id=null; cb_anonymous_id=%222c08c7ea-8a96-4a5b-90e3-05e994cd6e60%22; _fbp=fb.1.1637071934840.192595906; _rdt_uuid=1637071936866.f02b2ed8-5e72-451b-b8b2-9282d47d2fab; sliguid=781a4f49-c9ef-453c-b3f0-758d97457ce6; slirequested=true; __pdst=d3e5e20e63a9440bba61ce105ae50331; UserPrivacySettings=%7B%22AlertBoxClosed%22%3A%222021-11-16T14%3A12%3A57.412Z%22%2C%22Groups%22%3A%7B%22Targeting%22%3Atrue%7D%7D; keen={%22uuid%22:%22531c35b7-8163-4de0-a495-f79529a5885e%22%2C%22initialReferrer%22:%22https://www.upwork.com/%22}; _mkto_trk=id:518-RKL-392&token:_mch-upwork.com-1637072137411-46474; G_ENABLED_IDPS=google; recognized=b961bcc2; bmuid=1638741364576-E9A1FD6D-014C-4A63-A4C5-EBE68B785C8D; cdSNum=1638741355272-sjn0000365-d340b50f-30d9-4f54-a67b-1831c20163d8; odesk_signup.referer.raw=https%3A%2F%2Fwww.upwork.com%2F; device_view=full; _gid=GA1.2.373061672.1642794668; g_state={"i_p":1643399475556,"i_l":3}; profile_vv_gql_token=oauth2v2_b5d35a2c73b20bc628e389474da1c9a6; _pxhd=8bTVg1JcJQDbJOymZ3W1FgqXquqbscC7P4mhXglV6ME2QDb/wn2mHulsJWNFmVwrj79jIzNXoDODOCVNxxMMuw==:g6/GDndWnzMuknIZZN1QQXScnsapkDzhsGnJi6WfrHznyDUIq7Rt-1oYMA4JPO0iGVOz6vZd0FCiFpyz-sZk4i9Gcl-N8/Z9gXGNnKreIRw=; enabled_ff=CI11132Air2Dot75,CI9570Air2Dot5,!CI10270Air2Dot5QTAllocations,!CI10857Air3Dot0,!SSINav,!OTBnrOn,!OTBnr; survey_allowed=true; cookie_prefix=; cookie_domain=.upwork.com; __cf_bm=mpM7u9nlUZHoe8o2A_0d9HQ6qbZKJh9uewEXW6pJ_xg-1642956838-0-AS+9MR/i6q0Er4o8Re1rVr/QfIqTAiBcHbINIqFKNRFnAg7QBh7dXoPBgB4cyluzi2vfVwynMUlhWElDWwN4xrs=; __cfruid=86d921ca44ca3bf19feedd9c4ce180b22934ad3c-1642956838; pxcts=13053330-7c6d-11ec-a810-4b5745675267; _sp_ses.2a16=*; _hp2_ses_props.2858077939=%7B%22ts%22%3A1642956905673%2C%22d%22%3A%22www.upwork.com%22%2C%22h%22%3A%22%2F%22%7D; _dpm_ses.5831=*; prodperfect_session={%22session_uuid%22:%221b09915c-7156-4d82-b39f-cb4d58d65340%22}; IR_gbd=upwork.com; _clck=1pox0lh|1|eyd|0; visitor_gql_token=oauth2v2_3fd3504b0b1a1969ff08151e9390e3f3; _ga=GA1.2.1476560320.1637071917; IR_13634=1642957612536%7C0%7C1642957612536%7C%7C; _uetsid=7b1314407bc411ec9cf6b1f0210cd19f; _uetvid=34e379d046e711ecb049a57a717ec471; _clsk=ctyznp|1642957675336|3|0|f.clarity.ms/collect; vps_gql_token=oauth2v2_428d9a79b9e2e97f5fd6dcda310bb9ee; _ga_KSM221PNDX=GS1.1.1642956904.9.1.1642957724.0; XSRF-TOKEN=cb9cec42bcc325c83d2399c65ef14eab; _gat_UA-62227314-1=1; _px3=524ac87959ee474e5543044c59d80a79eadbf07dd4f2ade5abf8f6c729cb7713:cmmbUE31wzHFpKZ+8huSEBHKX/vI/FUf0dPLsKu69ciw8cbog1WGf1ygwAEaAW0R6b0D1R+cyyLuZl0ccw44Qg==:1000:1NLoCZHKdh32j7nv3VFjKAXF8HRJcBnfzU0AxtpXtDpM22QcLqKEVpbRHTlP3S6tPWreBqnAVPf/lVAdX5iJLharqSpESlt3ZHIGgAwiEA1JrQ2DWftFb5CQ5yOqUcoiW4xuAb/130sw8GhWW4xXCYfa62gzMbo1E31TQASRm4mh2Wzl7T2k2x/Xc+6ICoD1LSEpdvIbQ1ES+NBX+DD8hQ==; _sp_id.2a16=aab5df73-0280-4c06-a7d9-fc794ffc6938.1637071917.30.1642957731.1642887372.773371fd-000d-4403-ad49-0c0521ba9d4d; _hp2_props.2858077939=%7B%22container_id%22%3A%22GTM-P8M8MVZ%22%2C%22user_context%22%3A%22unknown%22%2C%22user_logged_in%22%3A%22unknown%22%7D; _hp2_id.2858077939=%7B%22userId%22%3A%222252629139422892%22%2C%22pageviewId%22%3A%228439814417873989%22%2C%22sessionId%22%3A%22784839734113609%22%2C%22identity%22%3A%221467602249194414080%22%2C%22trackerVersion%22%3A%224.0%22%2C%22identityField%22%3Anull%2C%22isIdentified%22%3A1%7D; _dc_gtm_UA-62227314-1=1; _dpm_id.5831=6bc2dd87-95fa-4cf3-ab0c-f84a6b5372d5.1637071939.30.1642957732.1642887374.100427a8-3bc3-434b-a35a-4cd511e36c40'
}
url = 'https://www.upwork.com/search/profiles/?page={}&pt=agency'
urls =[url.format(num+1) for num in range(200)]
list_of_id =[]
for u in urls:
  res = requests.get(u ,headers = headers)
  soup = BeautifulSoup(res.text,'html.parser')
  items = soup.find_all('div',class_='d-flex freelancer-tile')
  for i in items:
     id_freelancer = i.find('div',class_ = 'cfe-ui-freelancer-tile-identity flex-1 m-0 overflow-auto').get('data-qa-freelancer-ciphertext')
     list_of_id.append(id_freelancer)
     time.sleep(1.3)
#     Earned = i.find('div',class_='up-popper-trigger').text
#     Indice = i.find('span',class_='status-text d-flex top-rated-badge-status').text
#     first_skill = i.find('div',class_='up-skill-badge').text

# %%
print(len(list_of_id))
#print(urls)
# Out:
# 1780

# %%
url = 'https://www.upwork.com/freelancers/{}'
for i in id_freelancer:
    urls =[url.format(id)for id in list_of_id]

#print(urls)

# %%
columns_names = ['Nom','nationalité','Horaire_Total','total_jobs_hours','salary','hours_per_week' ,'agence_name','agence_job_succes','agence_hours']
df = pd.DataFrame(columns = columns_names)

# %% [markdown]
# ## Récupérer les infos des freelancers

# %% [markdown]
# COMMENCE A 13:54

# %%
headers = {
  'host': 'www.upwork.com',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36',
  'cookie': 'visitor_id=195.83.48.81.1637071873989010; lang=en; spt=5687a8e3-0b6f-458b-9ec7-5ea26a788067; _pxvid=0eabb6f8-46e7-11ec-9a3b-4e746f635050; _gcl_au=1.1.539077891.1637071917; cb_user_id=null; cb_group_id=null; cb_anonymous_id=%222c08c7ea-8a96-4a5b-90e3-05e994cd6e60%22; _fbp=fb.1.1637071934840.192595906; _rdt_uuid=1637071936866.f02b2ed8-5e72-451b-b8b2-9282d47d2fab; slirequested=true; sliguid=781a4f49-c9ef-453c-b3f0-758d97457ce6; __pdst=d3e5e20e63a9440bba61ce105ae50331; UserPrivacySettings=%7B%22AlertBoxClosed%22%3A%222021-11-16T14%3A12%3A57.412Z%22%2C%22Groups%22%3A%7B%22Targeting%22%3Atrue%7D%7D; keen={%22uuid%22:%22531c35b7-8163-4de0-a495-f79529a5885e%22%2C%22initialReferrer%22:%22https://www.upwork.com/%22}; _mkto_trk=id:518-RKL-392&token:_mch-upwork.com-1637072137411-46474; G_ENABLED_IDPS=google; recognized=b961bcc2; bmuid=1638741364576-E9A1FD6D-014C-4A63-A4C5-EBE68B785C8D; cdSNum=1638741355272-sjn0000365-d340b50f-30d9-4f54-a67b-1831c20163d8; odesk_signup.referer.raw=https%3A%2F%2Fwww.upwork.com%2F; _clck=1pox0lh|1|eya|0; _pxhd=zpYIYg39O8WWTqRJ6Ar9Fi7DekiI-rgfRL5z0boazFfKO6k6Olcgksvkr6ZRi5WOL/VHQ0NXwwI7FZKROrJfng==:02j8HCOVBHZN9CpLMgjvrx/oEHNijRmC7HcPXPkrBMyd5KOtXnb5ukyTwPjQd9qt-P8-hYWs7mT2aELh2QZl5tLpXo5M1suA6wbwPdf-oWE=; enabled_ff=CI11132Air2Dot75,CI9570Air2Dot5,!CI10270Air2Dot5QTAllocations,!CI10857Air3Dot0,!SSINav,!OTBnrOn,!OTBnr; survey_allowed=true; cookie_prefix=; cookie_domain=.upwork.com; __cf_bm=lC6WV4DOmtT5ryTaVaPaa9EKRFs6J.uEkfD2IUNhD2Y-1642794586-0-AeO1q0ndrGu/ZRNtIy3oFHXEhPzMGPa96Z12Onn1OHj07lNLPmKy9dRzq0i6VK2piOAtcPJAa74eedKI+BExetU=; __cfruid=942d0f441dd79bb0319d874cbf1f32ae4de92ec4-1642794586; device_view=full; pxcts=55df9e5a-7af3-11ec-8bd3-6c6f7354446d; _sp_ses.2a16=*; _gid=GA1.2.373061672.1642794668; _hp2_ses_props.2858077939=%7B%22r%22%3A%22https%3A%2F%2Fwww.google.com%2F%22%2C%22ts%22%3A1642794668045%2C%22d%22%3A%22www.upwork.com%22%2C%22h%22%3A%22%2F%22%7D; g_state={"i_p":1643399475556,"i_l":3}; channel=other; _dpm_ses.5831=*; IR_gbd=upwork.com; prodperfect_session={%22session_uuid%22:%2250db1762-3fcf-4f58-93c0-f8c2fa799e48%22}; visitor_gql_token=oauth2v2_eac7e7b7b647265c2a625e5d6bc78d34; IR_13634=1642794733054%7C0%7C1642794733054%7C%7C; _uetsid=8a6c14307af311ec9cb721ab5331e7d7; _uetvid=34e379d046e711ecb049a57a717ec471; _ga=GA1.2.1476560320.1637071917; _ga_KSM221PNDX=GS1.1.1642794667.7.1.1642794755.0; _px3=df7947991ec91fa57d098028da962706c8d3c56a054782a125abaeeb0df8f3e0:uvc067wWrKtvT30QU3vD5gP0xW45rA5tuiBYqK9uCvHQkSqFCV0KpypFkMOmE/7WTJ8191+vJO2Ikaqv1OfgdA==:1000:VB1PBxZ967+NlGVaatV2IZs/jDSH50MjGvJupxyudJNumjd8g2yJIp3sanM3O0gxCjtaOzl//mc+mlBUxtZ8bNuWKMyX/F1x1zB2DIA3vTxkOAAdDnmluaMAMpnMMPHJGfsgJN/G7Bi7PBY0svRkhiy95kZ1GjU2SU2+BvOKlVSRjs5edJImp18xzyxs1X/h1H1oUcb7b8iaXFqZ09tgnw==; _hp2_props.2858077939=%7B%22container_id%22%3A%22GTM-P8M8MVZ%22%2C%22user_context%22%3A%22unknown%22%2C%22user_logged_in%22%3A%22unknown%22%7D; _dpm_id.5831=6bc2dd87-95fa-4cf3-ab0c-f84a6b5372d5.1637071939.26.1642795020.1642681810.72e45abf-c793-4476-9d98-54ab2a0536c0; XSRF-TOKEN=a28f7c5fdbd52b04985332439c9971ab; _sp_id.2a16=aab5df73-0280-4c06-a7d9-fc794ffc6938.1637071917.26.1642795250.1642681807.9a37d1b3-3f8c-4445-aeb5-b4f5a13fa1fe; _hp2_id.2858077939=%7B%22userId%22%3A%222252629139422892%22%2C%22pageviewId%22%3A%222877579548423052%22%2C%22sessionId%22%3A%22280019533429718%22%2C%22identity%22%3A%221467602249194414080%22%2C%22trackerVersion%22%3A%224.0%22%2C%22identityField%22%3Anull%2C%22isIdentified%22%3A1%7D; vps_gql_token=oauth2v2_123f24018fb74d3a46465a921016bc61'
}
for u in urls:
    res = requests.get(u ,headers = headers)
    soup = BeautifulSoup(res.text,'html.parser')
    items = soup.find_all('div',class_='visitor-page-container')
    for i in items:
        Nom = i.find('h1',class_ = 'd-inline vertical-align-middle m-0').text
#        Titre = i.find('h2',class_ = 'mb-0 font-weight-black').text
#        Description = i.find('div',class_= 'up-line-clamp-wrapper col').text
        nationalité = i.find('div',class_ = 'd-block d-md-inline-block location').text
        Horaire_Total = i.find('div',class_ = 'cfe-ui-profile-summary-stats').text
#        Taux_horaire = i.find('h3',class_ = 'my-20').text     
#        job_success = i.find('div',class_ = 'cfe-ui-profile-job-success').text
        total_jobs_hours = i.find('div',class_ = 'd-flex').text
        salary = i.find('h3',class_='my-20').text
        hours_per_week = i.find('div',class_='mt-20').text
        agence_name = i.find('a',class_ = 'd-flex').text
        agence_job_succes = i.find('div',class_ ='ml-10').text
#        agence_top_rated = i.find('div',class_ ='mr-5 up-icon').text
        agence_hours = i.find('div', class_ ='ml-10').text
        time.sleep(1)
#        print(Nom,Titre,Description,nationalité,Horaire_Total,Taux_horaire,job_success,total_jobs_hours,salary,hours_per_week)
#        print(agence_name, agence_job_succes, agence_top_rated, agence_hours)
#        print() #affichage pour vérification
        df = df.append({'Nom': Nom,
                 'nationalité': nationalité,'Horaire_Total': Horaire_Total,
                 'total_jobs_hours': total_jobs_hours, 'salary': salary, 'hours_per_week': hours_per_week,'agence_name':agence_name,
                 'agence_job_succes': agence_job_succes,'agence_hours': agence_hours
                 }, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-81cb9794911c> in <module>
#      13 #        Description = i.find('div',class_= 'up-line-clamp-wrapper col').text
#      14         nationalité = i.find('div',class_ = 'd-block d-md-inline-block location').text
# ---> 15         Horaire_Total = i.find('div',class_ = 'cfe-ui-profile-summary-stats').text
#      16 #        Taux_horaire = i.find('h3',class_ = 'my-20').text
#      17 #        job_success = i.find('div',class_ = 'cfe-ui-profile-job-success').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ### Il y a des erreurs mais ce n'est pas grave parce que nous pouvons prendre les infos qu'il a déjà récupéré avec l'affichage d'erreur.

# %%
df
# Out:
#                                         Nom                    nationalité  \
# 0                         Anna A.                         Kharkiv, Ukraine
# 1                      Katrina B.             PASIG CITY 1611, Philippines
# 2                      Rosalie R.                 Makati City, Philippines
# 3                           Xi W.                           Beijing, China
# 4                        Haris A.                           Athens, Greece
# ..                                      ...                            ...
# 360       \n            Ivan P.\n                         Barcelona, Spain
# 361   \n            Nataliia B.\n                         Poltava, Ukraine
# 362  \n            Alexander S.\n                             Omsk, Russia
# 363    \n            Cynthia A.\n               Spring Glen, United States
# 364  \n            Elizaveta K.\n                             Omsk, Russia
#
#                        Horaire_Total  \
# 0     84 Total Jobs3,692 Total Hours
# 1    665 Total Jobs5,166 Total Hours
# 2      293 Total Jobs446 Total Hours
# 3       117 Total Jobs37 Total Hours
# 4     63 Total Jobs1,314 Total Hours
# ..                               ...
# 360      55 Total Jobs57 Total Hours
# 361   26 Total Jobs3,871 Total Hours
# 362   28 Total Jobs6,247 Total Hours
# 363   81 Total Jobs8,977 Total Hours
# 364   92 Total Jobs5,356 Total Hours
#
#                                       total_jobs_hours          salary  \
# 0    99%  Job Success        The percentage of this...    $40.00/hr
# 1    95%  Job Success        The percentage of this...    $30.00/hr
# 2    92%  Job Success        The percentage of this...    $20.00/hr
# 3    100%  Job Success        The percentage of thi...    $22.22/hr
# 4    100%  Job Success        The percentage of thi...   $270.00/hr
# ..                                                 ...             ...
# 360  100%  Job Success  \n      The percentage of t...  $25.00/hr\n
# 361  100%  Job Success  \n      The percentage of t...  $20.00/hr\n
# 362  100%  Job Success  \n      The percentage of t...  $45.00/hr\n
# 363                                                     $62.50/hr\n
# 364  100%  Job Success  \n      The percentage of t...  $40.00/hr\n
#
#                                         hours_per_week  \
# 0            Nov 3, 2021          -      Nov 17, 2021
# 1            Dec 9, 2021          -      Jan 11, 2022
# 2            Dec 9, 2021          -      Dec 19, 2021
# 3       Rating is 5 out of 5.     5.00       Nov 27...
# 4       Rating is 5 out of 5.     5.00       Jun 9,...
# ..                                                 ...
# 360    \n    Dec 17, 2018\n    \n      -\n      Feb...
# 361     Rating is 5 out of 5. \n    5.00\n   \n    ...
# 362    \n    May 21, 2020\n    \n      -\n      Aug...
# 363     Rating is 5 out of 5. \n    5.00\n   \n    ...
# 364     Rating is 4.55 out of 5. \n    4.55\n   \n ...
#
#                                         agence_name  \
# 0                                   PineDev Studio
# 1                                          Jackdog
# 2                                    iDocs Manager
# 3                                   sinovoices.com
# 4    Apeiron Digital Universe (former Greek Geeks)
# ..                                              ...
# 360                                        mattrs.
# 361                             Web Help Agency TM
# 362                                       Ronas IT
# 363               Amador Staffing Consultants, LLC
# 364                                       Ronas IT
#
#                                      agence_job_succes  \
# 0    99%  Job Success        The percentage of this...
# 1    95%  Job Success        The percentage of this...
# 2    92%  Job Success        The percentage of this...
# 3    100%  Job Success        The percentage of thi...
# 4    100%  Job Success        The percentage of thi...
# ..                                                 ...
# 360  100%  Job Success  \n      The percentage of t...
# 361  100%  Job Success  \n      The percentage of t...
# 362  100%  Job Success  \n      The percentage of t...
# 363
# 364  100%  Job Success  \n      The percentage of t...
#
#                                           agence_hours
# 0    99%  Job Success        The percentage of this...
# 1    95%  Job Success        The percentage of this...
# 2    92%  Job Success        The percentage of this...
# 3    100%  Job Success        The percentage of thi...
# 4    100%  Job Success        The percentage of thi...
# ..                                                 ...
# 360  100%  Job Success  \n      The percentage of t...
# 361  100%  Job Success  \n      The percentage of t...
# 362  100%  Job Success  \n      The percentage of t...
# 363
# 364  100%  Job Success  \n      The percentage of t...
#
# [365 rows x 9 columns]

# %% [markdown]
# ## Supression des singe \n parmi les données

# %%
for c in [column for column in df]:
    df[c] = df[c].apply(lambda x:x.replace('\n', '').replace('\r', ''))

# %%
df
# Out:
#                                     Nom                    nationalité  \
# 0                     Anna A.                         Kharkiv, Ukraine
# 1                  Katrina B.             PASIG CITY 1611, Philippines
# 2                  Rosalie R.                 Makati City, Philippines
# 3                       Xi W.                           Beijing, China
# 4                    Haris A.                           Athens, Greece
# ..                                  ...                            ...
# 360                   Ivan P.                         Barcelona, Spain
# 361               Nataliia B.                         Poltava, Ukraine
# 362              Alexander S.                             Omsk, Russia
# 363                Cynthia A.               Spring Glen, United States
# 364              Elizaveta K.                             Omsk, Russia
#
#                        Horaire_Total  \
# 0     84 Total Jobs3,692 Total Hours
# 1    665 Total Jobs5,166 Total Hours
# 2      293 Total Jobs446 Total Hours
# 3       117 Total Jobs37 Total Hours
# 4     63 Total Jobs1,314 Total Hours
# ..                               ...
# 360      55 Total Jobs57 Total Hours
# 361   26 Total Jobs3,871 Total Hours
# 362   28 Total Jobs6,247 Total Hours
# 363   81 Total Jobs8,977 Total Hours
# 364   92 Total Jobs5,356 Total Hours
#
#                                       total_jobs_hours         salary  \
# 0    99%  Job Success        The percentage of this...   $40.00/hr
# 1    95%  Job Success        The percentage of this...   $30.00/hr
# 2    92%  Job Success        The percentage of this...   $20.00/hr
# 3    100%  Job Success        The percentage of thi...   $22.22/hr
# 4    100%  Job Success        The percentage of thi...  $270.00/hr
# ..                                                 ...            ...
# 360  100%  Job Success        The percentage of thi...   $25.00/hr
# 361  100%  Job Success        The percentage of thi...   $20.00/hr
# 362  100%  Job Success        The percentage of thi...   $45.00/hr
# 363                                                      $62.50/hr
# 364  100%  Job Success        The percentage of thi...   $40.00/hr
#
#                                         hours_per_week  \
# 0            Nov 3, 2021          -      Nov 17, 2021
# 1            Dec 9, 2021          -      Jan 11, 2022
# 2            Dec 9, 2021          -      Dec 19, 2021
# 3       Rating is 5 out of 5.     5.00       Nov 27...
# 4       Rating is 5 out of 5.     5.00       Jun 9,...
# ..                                                 ...
# 360          Dec 17, 2018          -      Feb 7, 2021
# 361     Rating is 5 out of 5.     5.00       Dec 21...
# 362         May 21, 2020          -      Aug 19, 2020
# 363     Rating is 5 out of 5.     5.00       Jun 12...
# 364     Rating is 4.55 out of 5.     4.55       Sep...
#
#                                         agence_name  \
# 0                                   PineDev Studio
# 1                                          Jackdog
# 2                                    iDocs Manager
# 3                                   sinovoices.com
# 4    Apeiron Digital Universe (former Greek Geeks)
# ..                                              ...
# 360                                        mattrs.
# 361                             Web Help Agency TM
# 362                                       Ronas IT
# 363               Amador Staffing Consultants, LLC
# 364                                       Ronas IT
#
#                                      agence_job_succes  \
# 0    99%  Job Success        The percentage of this...
# 1    95%  Job Success        The percentage of this...
# 2    92%  Job Success        The percentage of this...
# 3    100%  Job Success        The percentage of thi...
# 4    100%  Job Success        The percentage of thi...
# ..                                                 ...
# 360  100%  Job Success        The percentage of thi...
# 361  100%  Job Success        The percentage of thi...
# 362  100%  Job Success        The percentage of thi...
# 363
# 364  100%  Job Success        The percentage of thi...
#
#                                           agence_hours
# 0    99%  Job Success        The percentage of this...
# 1    95%  Job Success        The percentage of this...
# 2    92%  Job Success        The percentage of this...
# 3    100%  Job Success        The percentage of thi...
# 4    100%  Job Success        The percentage of thi...
# ..                                                 ...
# 360  100%  Job Success        The percentage of thi...
# 361  100%  Job Success        The percentage of thi...
# 362  100%  Job Success        The percentage of thi...
# 363
# 364  100%  Job Success        The percentage of thi...
#
# [365 rows x 9 columns]

# %% [markdown]
# ## Mettre les données dans un fichier excel et le télécharger

# %%
with pd.ExcelWriter('angences2(-1).xlsx') as writer : 
    df.to_excel(writer,sheet_name='sheet1')
